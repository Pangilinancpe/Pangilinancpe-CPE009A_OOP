# %% [markdown]
# <a href="https://colab.research.google.com/github/Pangilinancpe/Pangilinancpe-CPE009A_OOP/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 5

i = 1
while i <= n:
    x = 0
    while x < i:
        print("*", end="")
        x += 1
    print()
    i += 1

i = n - 1
while i > 0:
    x = 0
    while x < i:
        print("*", end="")
        x += 1
    print()
    i -= 1
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
#Q24

a = ({[]}) = True

b = ([)] = False

c = ((())) = True

d = "({)} = False

print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
#   File "/tmp/ipykernel_492/2946213198.py", line 3
#     b = ([)] = False
#           ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
