# %% [markdown]
# <a href="https://colab.research.google.com/github/Pangilinancpe/Pangilinancpe-CPE009A_OOP/blob/main/Quiz_2_1_Practical_for_Module_2_Pangilinan_Jr_%2C_Bienvenido_B_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def termCrit(actNumber):
    rawScore = []
    totalScore = []

    for i in range(actNumber):
        print(f"\nActivity {i + 1}:")

        while True:
            s = float(input("Score: "))
            t = float(input("Total: "))

            if s > t:
                print("Invalid Score.")
            else:
                rawScore.append(s)
                totalScore.append(t)
                break

    grade = (sum(rawScore) / sum(totalScore)) * 100
    return grade

# %%
# Create a function for the class standing per term
def termCS():
  print("Hands-on Activities: ")
  termHOA = termCrit(int(input("\nHow many hands-on activities this term: ")))

  print("Quizzes:")
  termQuiz = termCrit(int(input("\nHow many quizzes this term: ")))

  print("Assignment: ")
  termAss = termCrit(int(input("\nHow many assignments: ")))

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")
  prelimGrade = termGrade()

  print("Midterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("Final Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  return finalFG

# %%
def convertGrade(FG):
  if FG >= 99:
        transmuted = 1.00
  elif FG >= 96:
        transmuted = 1.25
  elif FG >= 93:
        transmuted = 1.50
  elif FG >= 90:
        transmuted = 1.75
  elif FG >= 87:
        transmuted = 2.00
  elif FG >= 84:
        transmuted = 2.25
  elif FG >= 81:
        transmuted = 2.50
  elif FG >= 78:
        transmuted = 2.75
  elif FG >= 75:
        transmuted = 3.00
  else:
        transmuted = 5.00
  #The class should add everything else

# %%
final_percentage = semesterGrade()
point_grade = convertGrade(final_percentage)

print("-" * 30)
print(f"Final Percentage: {final_percentage:.2f}%")
print("-" * 30)
# Out:
# Prelim Grade
# Computing for the term grade.
# Exam Score: 10
# Exam Total: 10
# Hands-on Activities:
#
# How many hands-on activities this term: 1
#
# Activity 1:
# Score: 10
# Total: 0
# Invalid Score.
# Score: 10
# Total: 10
# Quizzes:
#
# How many quizzes this term: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Assignment:
#
# How many assignments: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Midterm Grade
# Computing for the term grade.
# Exam Score: 10
# Exam Total: 10
# Hands-on Activities:
#
# How many hands-on activities this term: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Quizzes:
#
# How many quizzes this term: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Assignment:
#
# How many assignments: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Final Grade
# Computing for the term grade.
# Exam Score: 10
# Exam Total: 10
# Hands-on Activities:
#
# How many hands-on activities this term: 1
#
# Activity 1:
# Score: 10
# Total: 10
# Quizzes:
#
# How many quizzes this term: 1
#
# ...

# %%
# Driver Code

# Trial 1
print(convertGrade(semesterGrade()))

# Trial 2

# Trial 3

# %% [markdown]
# **What is the difference from the code you created?**
#
# <Answer here> The whole is already ready to use and no need to change but depends on your use if you want it to more simplify or just stay put but my code on the first part, I changed it slightly by reducing some statement to make it statement short and the last part where I add statement that needed to convert grade into transmuted grade.
